# %%
### Data Ingestion

# %%
from langchain_community.utilities.pebblo import dir_loader
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the main content I am using for this RAG",
    metadata = {
        "author":"Om Parab",
        "date_created":"25-08-2026",
        "pages":1,
        "language":"English"
    }
)
doc
# Out:
# Document(metadata={'author': 'Om Parab', 'date_created': '25-08-2026', 'pages': 1, 'language': 'English'}, page_content='This is the main content I am using for this RAG')

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/mlops.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/mlops.txt'}, page_content="MicroMLOps: A Lightweight, Automated MLOps Pipeline for Small Teams and Limited Resource Environments\nProblem Statement\nModern MLOps practices such as automated retraining, data and model versioning, evaluation gating, and rollback are well established at large tech companies but remain out of reach for students, startups, and small teams due to the complexity and cost of tools like Kubeflow, SageMaker Pipelines, or Vertex AI. These platforms assume large budgets, dedicated infrastructure teams, and cloud scale compute. As a result, many small teams either skip MLOps entirely, leading to untracked model versions, undocumented datasets, and manual deployments, or they waste significant effort building brittle one off scripts. This project addresses that gap by building a lightweight, opinionated MLOps pipeline that provides the core benefits of versioning, automated retraining, evaluation gating, and rollba
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

###Load all files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt",  #pattern to match files
    loader_cls = TextLoader,    #class to use
    loader_kwargs = {"encoding": "utf-8"},
    show_progress = True
)

# %%
from langchain_community.document_loaders import PyMuPDFLoader

###Load all files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",  #pattern to match files
    loader_cls = PyMuPDFLoader,  #class to use
    show_progress = False
)
pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'GPL Ghostscript 9.56.1', 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'creationdate': "D:20251016072905Z00'00'", 'source': '../data/pdf/mlops_roadmap.pdf', 'file_path': '../data/pdf/mlops_roadmap.pdf', 'total_pages': 21, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20251016072905Z00'00'", 'trapped': '', 'modDate': "D:20251016072905Z00'00'", 'creationDate': "D:20251016072905Z00'00'", 'page': 0}, page_content='MLOps Roadmap\nYour Beginner-Friendly Guide to Machine Learning Operations\nby TechWorld with Nana'),
# ...
